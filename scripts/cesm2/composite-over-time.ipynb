# %% [markdown]
# # ENSO composite over time

# %% [markdown]
# ## imports

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import seaborn as sns
import xarray as xr
import tqdm
import pathlib
import cmocean
import os
import copy
import time

# Import custom modules
import src.utils

## set plotting specs
sns.set(rc={"axes.facecolor": "white", "axes.grid": False})

## bump up DPI
mpl.rcParams["figure.dpi"] = 100

## get filepaths
DATA_FP = pathlib.Path(os.environ["DATA_FP"])
SAVE_FP = pathlib.Path(os.environ["SAVE_FP"])

# %% [markdown]
# ## Funcs

# %%
def get_dT_sub(Tsub, Hm, delta=25):
    """
    Get temperature difference b/n entrainment zone and mixed layer.
    (positive if entrainment zone is warmer than ML)
    """

    ## find indices in ML and entrainment zone (ez)
    in_ml = Tsub.z_t <= Hm
    in_ez = (Tsub.z_t > Hm) & (Tsub.z_t < (delta + Hm))

    ## get Tbar and Tplus (following Frankignoul et al paper)
    Tbar = Tsub.where(in_ml).mean("z_t")
    Tplus = Tsub.where(in_ez).mean("z_t")

    ## get gradient
    dT = Tplus - Tbar

    return dT


def prep(data):
    """remove sst dependence and compute tendencies"""

    ## remove from h indices
    for h_idx in ["h_w", "h", "h_w_z20"]:
        data[f"{h_idx}_hat"] = src.utils.remove_sst_dependence_v2(
            data, h_var=h_idx, T_var="T_34"
        )

    return data


def load_budget_data(t_early, t_late, target_grid):
    """load ground truth heat budget data"""

    def load_var(varname):
        """load variable from prepped folder"""

        ## open data
        data = xr.open_mfdataset(
            sorted(list(pathlib.Path(DATA_FP, "cesm", f"{varname}_temp").glob("*.nc"))),
            concat_dim="member",
            combine="nested",
            parallel=True,
        )

        return data.assign_coords({"member": np.arange(100)})

    ## load data
    budget_data = xr.merge([load_var(v) for v in ["adv", "ddt_T"]])

    ## get difference
    # budget_data["diff"] = budget_data["TEND_TEMP"] - budget_data["ADV_3D_TEMP"]

    ## convert z coord from cm to m, and unit from K/s to K/mo
    M_PER_CM = 1e-2
    SEC_PER_MO = 8.64e4 * 30

    ## convert from (i) cm to m and (ii) K/s to K/mo
    budget_data = budget_data.assign_coords({"z_t": budget_data.z_t * M_PER_CM})
    budget_data = budget_data * SEC_PER_MO

    ## fix longitude coordinate
    budget_data = budget_data.assign_coords({"nlon": budget_data.lon.values})
    budget_data = budget_data.drop_vars("lon").rename({"nlon": "longitude"})

    ## trim in time
    budget_data = xr.concat(
        [budget_data.sel(t_early), budget_data.sel(t_late)], dim="time"
    )

    ## interpolate
    budget_data = budget_data.interp_like(target_grid)

    # ## separate forced/anomalies
    forced_bud, anom_bud = src.utils.separate_forced(budget_data)

    return forced_bud, anom_bud


def plot_mlds(axs, bar_early, bar_late, month=None):
    """plot mixed layer depth on pair of axs objects"""

    ## get longitude
    lon = src.utils.merimean(bar_early).longitude

    ## helper function to get month
    if month is None:
        sel = lambda x: x.mean("month")
    else:
        sel = lambda x: x.sel(month=month)

    ## plot
    axs[0].plot(lon, sel(src.utils.merimean(bar_early["mld"])), c="k")
    axs[1].plot(lon, sel(src.utils.merimean(bar_late["mld"])), c="k", ls="--")
    axs[2].plot(lon, sel(src.utils.merimean(bar_early["mld"])), c="k")
    axs[2].plot(lon, sel(src.utils.merimean(bar_late["mld"])), c="k", ls="--")

    return


def get_nino3_da(x):
    """get nino3 on dataarray"""

    if "latitude" not in x.dims:
        x = x.expand_dims("latitude")

    return src.utils.get_nino3(x)


def get_nino34_da(x):
    """get nino3.4 on dataarray"""

    if "latitude" not in x.dims:
        x = x.expand_dims("latitude")

    return src.utils.get_nino34(x)


def get_composite(idx, data, peak_month, q=0.95, is_warm=True, event_type=None):
    """
    Get hovmoller composite based on specified:
    - data: used to compute index/make composite
    - peak_month: month to center composite on
    - q: quantile threshold for composite
    """

    ## handle warm/cold case
    if is_warm:
        kwargs = dict(q=q, check_cutoff=lambda x, cut: x > cut)
    else:
        kwargs = dict(q=1 - q, check_cutoff=lambda x, cut: x < cut)

    ## kwargs for composite
    kwargs = dict(
        kwargs, peak_month=peak_month, idx=idx, data=data, event_type=event_type
    )

    ## composite of projected data
    comp_proj = src.utils.make_composite(**kwargs)

    return comp_proj


def get_spatial_composite(data, **composite_kwargs):
    """
    Get spatial composite
    """

    ## pull out components
    components, scores = src.utils.split_components(data)

    ## get projected composite
    comp_proj = get_composite(data=scores, **composite_kwargs)

    ## reconstruct spatial fields
    comp = reconstruct_helper(comp_proj, components, func=lambda x: x).drop_vars("mode")

    # ## reconstruct relative SST
    # comp["sst_rel"] = comp["sst_total"] - comp["trop_sst_05"]

    return comp


def reconstruct_helper(composite, components, func):
    """reconstruction helper function for composite"""

    ## copy to hold reconstructed results
    composite_recon = copy.deepcopy(composite)

    ## reconstruct anomalies
    for c in list(components):
        composite_recon[c] = src.utils.reconstruct_fn(
            components=components[c],
            scores=composite[c],
            fn=func,
        )

    ## check for "total" fields
    for c in list(composite):
        if "_total" in c:
            n = c[:-6]
            if n in list(components):
                composite_recon[c] = src.utils.reconstruct_fn(
                    components=components[n],
                    scores=composite[c],
                    fn=func,
                )

    return composite_recon


def get_spatial_clim(forced, lags, peak_month, fn=lambda x: x):
    """get climatologies of spatial variables"""

    ## reconstruct monthly climatology for period
    clim = src.utils.reconstruct_clim(data=forced, fn=fn)

    ## convert to lag coordinates
    months = 1 + np.mod(lags + peak_month - 1, 12)
    clim_comp = xr.concat(
        [clim.sel(month=m).drop_vars("month") for m in months],
        dim=lags,
    )

    return clim_comp


def get_T_ml_tendency(T, mld, delta=5, H0=None):
    """compute mixed-layer temperature tendency"""

    ## integrate over mixed layer
    T_ml = src.utils.get_ml_avg(T, Hm=mld, delta=delta, H0=H0)

    ## compute tendency
    return T_ml.differentiate("lag")


def get_spatial_composite_wrapper(
    data,
    forced_scores,
    peak_month,
    H0=None,
    **composite_kwargs,
):
    """
    Get spatial composite
    """

    ## get spatial composite of anomalies
    composite = get_spatial_composite(
        data=data,
        peak_month=peak_month,
        **composite_kwargs,
    )

    ## get background state
    comp_clim = get_spatial_clim(
        forced=forced_scores,
        lags=composite.lag,
        peak_month=peak_month,
    )

    ## get thermocline depth
    H_clim = src.utils.get_H_int(comp_clim["T"], thresh=0.04)
    H_full = src.utils.get_H_int(comp_clim["T"] + composite["T"], thresh=0.04)
    comp_clim["H"] = H_clim
    composite["H"] = H_full - H_clim

    ## compute ocean feedbacks
    feedbacks = src.utils.get_feedbacks(bar=comp_clim, prime=composite)
    composite = xr.merge([composite, feedbacks])

    ## get differences
    # composite["diff"] = composite["TEND_TEMP"] - composite["ADV_3D_TEMP"]

    ## add SST tendency
    # composite["ddt_sst"] = composite["sst"].differentiate("lag")
    # composite["ddt_ssh"] = composite["ssh"].differentiate("lag")
    # composite["ddt_z20"] = composite["z20"].differentiate("lag")
    # composite["ddt_ssh_hat"] = composite["ssh_hat"].differentiate("lag")

    ## get NHF in units of K/mo
    sec_per_mo = 8.64e4 * 30
    rho = 1.02e3
    Cp = 4.2e3

    ## get H
    if H0 is None:
        H = comp_clim["mld"]
    else:
        H = H0

    composite["Q"] = composite["nhf"] * sec_per_mo / (rho * Cp * H)

    return composite, comp_clim

# %% [markdown]
# ## Load data

# %% [markdown]
# ### $T$, $h$

# %%
## open data
Th = src.utils.load_cesm_indices(load_z20=True)

## rename indices for convenience
Th = Th.rename(
    {
        "north_tropical_atlantic": "natl",
        "atlantic_nino": "nino_atl",
        "tropical_indian_ocean": "iobm",
        "indian_ocean_dipole": "iod",
        "north_pacific_meridional_mode": "npmm",
        "south_pacific_meridional_mode": "spmm",
    }
)

## load tropical SST avg
trop_sst = xr.open_dataset(pathlib.Path(DATA_FP, "cesm/trop_sst.nc"))

## Load T,h (total)
Th_total = xr.open_dataset(DATA_FP / "cesm" / "Th.nc")

## compute relative sst
for n in ["T_3", "T_34", "T_4"]:
    Th[f"{n}_rel"] = Th_total[n] - trop_sst["trop_sst_10"]

# %% [markdown]
# #### Compute composite

# %%
## specify what variable to use
VARNAME = "T_34"

## specify shared args
kwargs = dict(
    peak_month=12,
    q=0.95,
    event_type=1,
    H0=70,
)

## save filepath
SAVE_DIR = pathlib.Path(os.environ["SAVE_FP"], "composites", f"{VARNAME}_{kwargs['q']}")


if (SAVE_DIR / "cold.nc").is_file():
    try:
        comps_cold = xr.open_dataset(SAVE_DIR / "cold.nc")
        comps_warm = xr.open_dataset(SAVE_DIR / "warm.nc")
        clim = xr.open_dataset(SAVE_DIR / "clim.nc")
    except:
        print("error...")

else:

    ## load data
    forced, anom = src.utils.load_consolidated()
    anom = xr.merge([anom, Th / Th.std()])

    ## "window" it
    anom = src.utils.get_windowed(anom, stride=120).compute()
    forced = src.utils.get_windowed(forced, stride=120).compute()

    ## empty array to hold coefficients
    comps_cold = []
    comps_warm = []
    clims = []

    for y in tqdm.tqdm(anom.year):

        ## get args for composite
        comp_kwargs = dict(
            idx=anom[VARNAME].sel(year=y),
            forced_scores=forced.sel(year=y),
            data=anom.sel(year=y),
        )

        ## warm
        comp_warm, clim = get_spatial_composite_wrapper(
            is_warm=True,
            **comp_kwargs,
            **kwargs,
        )

        ## cold
        comp_cold, _ = get_spatial_composite_wrapper(
            is_warm=False,
            **comp_kwargs,
            **kwargs,
        )

        ## append to list
        clims.append(clim)
        comps_warm.append(comp_warm)
        comps_cold.append(comp_cold)

    ## convert to xarray
    comps_warm = xr.concat(comps_warm, dim=anom.year)
    comps_cold = xr.concat(comps_cold, dim=anom.year)
    clims = xr.concat(clims, dim=anom.year)

    ## save to fild
    comps_cold.to_netcdf(SAVE_DIR / "cold.nc")
    comps_warm.to_netcdf(SAVE_DIR / "warm.nc")
    clims.to_netcdf(SAVE_DIR / "clim.nc")

# %% [markdown]
# Mixed layer averages

# %%
ml_kwargs = dict(H0=70, Hm=None)
comps_cold = src.utils.get_ml_avg_ds(comps_cold, **ml_kwargs)
comps_warm = src.utils.get_ml_avg_ds(comps_warm, **ml_kwargs)

## get time tendency
for comp in [comps_cold, comps_warm]:
    comp["ddt_T_ml"] = comp["T_ml"].differentiate("lag")

# %% [markdown]
# ### Plot

# %%
def plot_cycle_hov_lagged(
    ax,
    data,
    amp,
    is_filled=True,
    xticks=[190, 240],
    lat_bound=5,
    nlev=5,
    cmap="cmo.balance",
    levels=None,
):
    """plot data on ax object"""

    ## set levels if not specified
    if levels is None:
        levels = src.utils.make_cb_range(amp, amp / nlev)

    ## specify shared kwargs
    shared_kwargs = dict(levels=levels, extend="both")

    ## specify kwargs
    if is_filled:
        plot_fn = ax.contourf
        kwargs = dict(cmap=cmap)

    else:
        plot_fn = ax.contour
        kwargs = dict(colors="k", linewidths=0.8)

    ## average over latitudes (if necessary)
    if "latitude" in data.coords:
        plot_data = src.utils.merimean(data, lat_bound=lat_bound)
    else:
        plot_data = data

    ## do the plotting
    cp = plot_fn(
        plot_data.longitude,
        plot_data.lag,
        plot_data.transpose("lag", "longitude"),
        **kwargs,
        **shared_kwargs,
    )

    ## format ax object
    kwargs = dict(c="w", ls="--", lw=0.8, alpha=0.5)
    ax.set_xlim([145, 280])
    ax.set_xlabel("Lon")
    ax.set_xticks(xticks)
    for tick in xticks:
        ax.axvline(tick, **kwargs)
    ax.axhline(0, **kwargs)

    return cp


def format_hov_axs(axs, peak_mon):
    """format hov axs"""

    ## label
    font_kwargs = dict(size=10)
    axs[0].set_title("Early", **font_kwargs)
    axs[1].set_title("Late", **font_kwargs)
    axs[2].set_title("Difference (scaled)", **font_kwargs)
    for ax in axs:
        ax.set_yticks([])

    src.utils.label_hov_yaxis(axs[0], peak_mon=peak_mon)

    return axs


def plot_eli_on_axs(axs, x0, x1, name="eli_05"):
    """plot ELI boundary on hovmoller axs"""

    ## plot ELI
    axs[0].plot(x0[name], x0.lag, c="magenta")
    axs[1].plot(x1[name], x1.lag, c="magenta", ls="--")
    axs[2].plot(x0[name], x0.lag, c="magenta", ls="-")
    axs[2].plot(x1[name], x1.lag, c="magenta", ls="--")

    return


def plot_level(ax, comp, level, ls="-", c="magenta"):
    """plot single level on hovmoller"""
    ax.contour(
        comp.longitude,
        comp.lag,
        comp.transpose("lag", ...),
        levels=[level],
        colors=c,
        linestyles=ls,
    )
    return


def plot_sst_rel_on_axs(axs, x0, x1, lev=0):
    """plot ELI boundary on hovmoller axs"""

    ## plot ELI
    plot_level(axs[0], x0["sst_rel"], level=lev)
    plot_level(axs[1], x1["sst_rel"], level=lev, ls="--")
    plot_level(axs[2], x0["sst_rel"], level=lev)
    plot_level(axs[2], x1["sst_rel"], level=lev, ls="--")

    return


def plot_comp_on_axs(
    axs,
    x0,
    x1,
    name,
    amp,
    peak_month,
    amp_diff=None,
    nlev=5,
    **kwargs,
):
    """plot composite on axs objects"""

    ## handle amp_diff=None
    if amp_diff is None:
        amp_diff = amp / 2

    ## loop thru: x0, x1, (x1-x0)
    for ax, x in zip(axs, [x0, x1, (amp / amp_diff) * (x1 - x0)]):

        ## Plot data and suppress y-axis plot
        cf = plot_cycle_hov_lagged(ax=ax, data=x[name], amp=amp, nlev=nlev, **kwargs)

    ## format/label
    format_hov_axs(axs, peak_mon=peak_month)

    return cf

# %% [markdown]
# ### show plots

# %%
## shared args
hov_kwargs = dict(
    peak_month=kwargs["peak_month"],
)
merimean = lambda x: x.sel(latitude=slice(-5, 5)).mean("latitude")

norm = lambda x: x / x["T_3"]

# %% [markdown]
# #### SST

# %%
## set up plot
fig, axs = plt.subplots(1, 3, figsize=(7, 3), layout="constrained")

## plot data
cf = plot_comp_on_axs(
    axs,
    name="sst",
    amp=3.5,
    amp_diff=3.5 / 4,
    x0=comps_warm.sel(year=1870),
    x1=comps_warm.sel(year=2080),
    nlev=10,
    **hov_kwargs,
)

## label
cb = fig.colorbar(cf, ax=axs[2], ticks=[-2.5, 0, 2.5], label="K")

plt.show()

# %%
eq_peak = comps_warm.sel(latitude=slice(-5, 5), lag=0).mean("latitude")
# eq_peak = -comps_cold.sel(latitude=slice(-5,5), lag=0).mean("latitude")

# %%
fig, ax = plt.subplots(figsize=(4, 3))

for y in np.arange(1870, 2120, 50):
    ax.plot(eq_peak.longitude, eq_peak["sst"].sel(year=y), label=y)
    ax.set_xlim([140, 280])

ax.legend()

# %%
import cartopy.crs as ccrs

## specify which month to look at
COMP = comps_warm["sst"].sel(lag=1)
# COMP = (clim)["taux"].sel(lag=1)

fig = plt.figure(figsize=(7.5, 3), layout="constrained")
format_func = lambda ax,: src.utils.plot_setup_pac(ax, max_lat=15)
axs = src.utils.subplots_with_proj(fig, nrows=3, ncols=1, format_func=format_func)

kwargs = dict(
    cmap="cmo.balance",
    levels=src.utils.make_cb_range(4, 0.4),
    extend="both",
    transform=ccrs.PlateCarree(),
)


## plot early
axs[0, 0].contourf(COMP.longitude, COMP.latitude, COMP.sel(year=1870), **kwargs)
axs[1, 0].contourf(COMP.longitude, COMP.latitude, COMP.sel(year=2080), **kwargs)
axs[2, 0].contourf(
    COMP.longitude,
    COMP.latitude,
    4 * (COMP.sel(year=2080) - COMP.sel(year=1870)),
    **kwargs
)


for ax in axs.flatten():
    ax.axhline(5, ls="--", c="k")
    ax.axhline(-5, ls="--", c="k")

plt.show()

# %% [markdown]
# SSH

# %%
sel_ = lambda x: x.sel(latitude=slice(-5, 5)).mean("latitude")

# %%
## set up plot
fig, axs = plt.subplots(1, 3, figsize=(7, 3), layout="constrained")

## plot data
cf = plot_comp_on_axs(
    axs,
    name="ssh",
    amp=10,
    amp_diff=5,
    x0=(sel_(comps_cold) / comps_cold["T_3"]).sel(year=1870),
    x1=(sel_(comps_cold) / comps_cold["T_3"]).sel(year=2080),
    # x0=(sel_(comps_warm)/comps_warm["T_3"]).sel(year=1870),
    # x1=(sel_(comps_warm)/comps_warm["T_3"]).sel(year=2080),
    # x0=comps_warm.sel(year=1870),
    # x1=comps_warm.sel(year=2080),
    nlev=10,
    **hov_kwargs,
)

for ax in axs:
    ax.set_xlim([120, None])

## label
cb = fig.colorbar(cf, ax=axs[2], ticks=[-2.5, 0, 2.5], label="K")

plt.show()

# %%
plt.plot(
    comps_cold.longitude,
    (sel_(comps_cold["ssh"]) / comps_cold["T_34"]).sel(year=1870).sel(lag=2),
)
plt.plot(
    comps_cold.longitude,
    (sel_(comps_cold["ssh"]) / comps_cold["T_34"]).sel(year=2080).sel(lag=2),
)

# %%
import cartopy.crs as ccrs

## specify which month to look at
# COMP = comps_warm["ssh"].sel(lag=1)
# COMP = (comps_warm["ssh"]/comps_warm["T_3"]).sel(lag=1)
COMP = (comps_cold["ssh"] / comps_cold["T_3"]).sel(lag=1)
# COMP = (clim)["taux"].sel(lag=1)

fig = plt.figure(figsize=(7.5, 3), layout="constrained")
format_func = lambda ax,: src.utils.plot_setup_pac(ax, max_lat=15)
axs = src.utils.subplots_with_proj(fig, nrows=3, ncols=1, format_func=format_func)

kwargs = dict(
    cmap="cmo.balance",
    levels=src.utils.make_cb_range(7.5, 0.75),
    extend="both",
    transform=ccrs.PlateCarree(),
)


## plot early
axs[0, 0].contourf(COMP.longitude, COMP.latitude, COMP.sel(year=1870), **kwargs)
axs[1, 0].contourf(COMP.longitude, COMP.latitude, COMP.sel(year=2080), **kwargs)
axs[2, 0].contourf(
    COMP.longitude,
    COMP.latitude,
    2 * (COMP.sel(year=2080) - COMP.sel(year=1870)),
    **kwargs
)


for ax in axs.flatten():
    ax.axhline(5, ls="--", c="k")
    ax.axhline(-5, ls="--", c="k")

plt.show()

# %%
## set up plot
fig, axs = plt.subplots(1, 3, figsize=(7, 3), layout="constrained")

## plot data
cf = plot_comp_on_axs(
    axs,
    name="taux",
    amp=5e-2,
    amp_diff=2e-2,
    x0=comps_warm.sel(year=1870),
    x1=comps_warm.sel(year=2080),
    nlev=10,
    **hov_kwargs,
)

## label
cb = fig.colorbar(cf, ax=axs[2], ticks=[-2.5, 0, 2.5], label="K")
for ax in axs:
    ax.axhline(2, ls="--", c="w", lw=0.8)

plt.show()

# %%
import cartopy.crs as ccrs

## specify which month to look at
COMP = -comps_warm["tauy"].sel(lag=1)
# COMP = (clim)["taux"].sel(lag=1)

fig = plt.figure(figsize=(7.5, 3), layout="constrained")
format_func = lambda ax,: src.utils.plot_setup_pac(ax, max_lat=15)
axs = src.utils.subplots_with_proj(fig, nrows=3, ncols=1, format_func=format_func)

kwargs = dict(
    cmap="cmo.balance",
    levels=src.utils.make_cb_range(4e-2, 4e-3),
    extend="both",
    transform=ccrs.PlateCarree(),
)


## plot early
axs[0, 0].contourf(COMP.longitude, COMP.latitude, COMP.sel(year=1870), **kwargs)
axs[1, 0].contourf(COMP.longitude, COMP.latitude, COMP.sel(year=2080), **kwargs)
axs[2, 0].contourf(
    COMP.longitude,
    COMP.latitude,
    2 * (COMP.sel(year=2080) - COMP.sel(year=1870)),
    **kwargs
)


for ax in axs.flatten():
    ax.axhline(5, ls="--", c="k")
    ax.axhline(-5, ls="--", c="k")

plt.show()

# %%
import cartopy.crs as ccrs

## specify which month to look at
# COMP = (comps_warm["pr"].sel(lag=1) + clim["pr"].sel(lag=1))
# COMP = (clim["pr"]+comps_warm["pr"]).sel(lag=0)
# COMP = (clim["sst"]).sel(lag=0)
COMP = (clim["sst"] + comps_warm["sst"]).sel(lag=0)
# COMP = (comps_warm["sst"]).sel(lag=0)
# COMP = comps_warm["pr"].sel(lag=0)
# COMP = (clim["pr"].sel(lag=1))

fig = plt.figure(figsize=(7.5, 3), layout="constrained")
format_func = lambda ax,: src.utils.plot_setup_pac(ax, max_lat=15)
axs = src.utils.subplots_with_proj(fig, nrows=3, ncols=1, format_func=format_func)

kwargs = dict(
    # cmap="cmo.balance",
    # levels=src.utils.make_cb_range(4, 0.4),
    cmap="cmo.thermal",
    levels=np.arange(20, 35, 1),
    extend="both",
    transform=ccrs.PlateCarree(),
)


## plot early
axs[0, 0].contourf(COMP.longitude, COMP.latitude, COMP.sel(year=1870), **kwargs)
axs[1, 0].contourf(COMP.longitude, COMP.latitude, COMP.sel(year=2080), **kwargs)
axs[2, 0].contourf(
    COMP.longitude,
    COMP.latitude,
    (COMP.sel(year=2080) - COMP.sel(year=1870)),
    cmap="cmo.balance",
    levels=src.utils.make_cb_range(2, 0.2),
    extend="both",
    transform=ccrs.PlateCarree(),
)


for ax in axs.flatten():
    ax.axhline(5, ls="--", c="k")
    ax.axhline(-5, ls="--", c="k")

plt.show()

# %%
sel0 = lambda x: x.sel(latitude=slice(-5, 5)).mean("latitude")
sel = lambda x: sel0(x) - sel0(x).mean("longitude")
# sel = lambda x : sel0(x)
plt.plot(COMP.longitude, sel(COMP.isel(year=0)))
plt.plot(COMP.longitude, sel(COMP.isel(year=-1)))
plt.axvline(190)

# %%
import cartopy.crs as ccrs

## specify which month to look at
# COMP = (comps_warm["pr"].sel(lag=1) + clim["pr"].sel(lag=1))
# COMP = (clim["pr"]+comps_warm["pr"]).sel(lag=0)
# COMP = (comps_warm["pr"] / comps_warm["T_34"]).sel(lag=0)
COMP = comps_cold["pr"].sel(lag=1)
# COMP = (clim["pr"].sel(lag=1))

fig = plt.figure(figsize=(7.5, 3), layout="constrained")
format_func = lambda ax,: src.utils.plot_setup_pac(ax, max_lat=15)
axs = src.utils.subplots_with_proj(fig, nrows=3, ncols=1, format_func=format_func)

kwargs = dict(
    # cmap="cmo.rain",
    # levels=np.arange(0, 3e-4, 3e-5),
    cmap="cmo.balance_r",
    levels=src.utils.make_cb_range(1.5e-4, 1.5e-5),
    extend="max",
    transform=ccrs.PlateCarree(),
)


## plot early
axs[0, 0].contourf(COMP.longitude, COMP.latitude, COMP.sel(year=1870), **kwargs)
axs[1, 0].contourf(COMP.longitude, COMP.latitude, COMP.sel(year=2080), **kwargs)
axs[2, 0].contourf(
    COMP.longitude,
    COMP.latitude,
    (COMP.sel(year=2080) - COMP.sel(year=1870)),
    cmap="cmo.balance_r",
    levels=src.utils.make_cb_range(1.5e-4, 1.5e-5),
    extend="both",
    transform=ccrs.PlateCarree(),
)


for ax in axs.flatten():
    ax.axhline(5, ls="--", c="k")
    ax.axhline(-5, ls="--", c="k")

plt.show()

# %%
max_lon_idx = (
    comps_warm["pr"]
    .sel(lag=0, latitude=slice(-5, 5))
    .mean("latitude")
    .sel(longitude=slice(140, 280))
    .argmax("longitude")
)
plt.plot(
    comps_warm.year,
    comps_warm.sel(longitude=slice(140, 280)).longitude.isel(
        longitude=max_lon_idx.values
    ),
)

# %%
plt.plot(COMP.longitude, COMP.isel(year=0).sel(latitude=slice(-5, 5)).mean("latitude"))
plt.plot(COMP.longitude, COMP.isel(year=-1).sel(latitude=slice(-5, 5)).mean("latitude"))
plt.axvline(190)

# %%
plt.plot(
    COMP.latitude, COMP.sel(longitude=slice(140, 280)).mean("longitude").isel(year=0)
)
plt.plot(
    COMP.latitude, COMP.sel(longitude=slice(140, 280)).mean("longitude").isel(year=-1)
)
plt.xlim([-10, 10])

# %%
import cartopy.crs as ccrs

## specify which month to look at
# COMP = (comps_warm["pr"].sel(lag=1) + clim["pr"].sel(lag=1))
# COMP = (clim+comps_warm)["nhf"].sel(lag=0)
COMP = (comps_warm["nhf"]).sel(lag=0)
# COMP = (clim["pr"].sel(lag=1))

fig = plt.figure(figsize=(7.5, 3), layout="constrained")
format_func = lambda ax,: src.utils.plot_setup_pac(ax, max_lat=15)
axs = src.utils.subplots_with_proj(fig, nrows=3, ncols=1, format_func=format_func)

kwargs = dict(
    cmap="cmo.balance",
    levels=src.utils.make_cb_range(80, 8),
    extend="both",
    transform=ccrs.PlateCarree(),
)


## plot early
axs[0, 0].contourf(COMP.longitude, COMP.latitude, COMP.sel(year=1870), **kwargs)
axs[1, 0].contourf(COMP.longitude, COMP.latitude, COMP.sel(year=2080), **kwargs)
axs[2, 0].contourf(
    COMP.longitude,
    COMP.latitude,
    (COMP.sel(year=2080) - COMP.sel(year=1870)),
    cmap="cmo.balance",
    levels=src.utils.make_cb_range(40, 4),
    extend="both",
    transform=ccrs.PlateCarree(),
)


for ax in axs.flatten():
    ax.axhline(5, ls="--", c="k")
    ax.axhline(-5, ls="--", c="k")

plt.show()

# %%
h0 = comps_warm["ssh"].sel(year=1870).sel(longitude=slice(210, 270)).mean("longitude")
h1 = comps_warm["ssh"].sel(year=2090).sel(longitude=slice(210, 270)).mean("longitude")

# %%
LAG = 2

fig, axs = plt.subplots(3, 1, figsize=(4, 7))
axs[0].contourf(
    h0.lag,
    h0.latitude,
    h0.differentiate("lag"),
    cmap="cmo.balance",
    levels=src.utils.make_cb_range(8, 0.8),
)
axs[1].contourf(
    h0.lag,
    h0.latitude,
    h1.differentiate("lag"),
    cmap="cmo.balance",
    levels=src.utils.make_cb_range(8, 0.8),
)
axs[2].contourf(
    h0.lag,
    h0.latitude,
    2 * (h1 - h0).differentiate("lag"),
    cmap="cmo.balance",
    levels=src.utils.make_cb_range(8, 0.8),
)

for ax in axs:
    ax.set_ylim([-10, 10])
    ax.axvline(0, ls="--", c="k")
    ax.axhline(0, ls="--", c="k")

# %%
## set up plot
fig, axs = plt.subplots(1, 3, figsize=(7, 3), layout="constrained")

## plot data
cf = plot_comp_on_axs(
    axs,
    name="sst",
    amp=3.5,
    x0=comps_warm.sel(year=1870),
    x1=comps_warm.sel(year=2070),
    nlev=10,
    **hov_kwargs,
)

## label
cb = fig.colorbar(cf, ax=axs[2], ticks=[-2.5, 0, 2.5], label="K")

plt.show()

# %% [markdown]
# #### latitude hovmollers

# %%
# LON_RANGE=slice(150,240)
LON_RANGE = slice(210, 270)
# LON_RANGE=slice(240,275)
lon_avg = lambda x: x.sel(longitude=LON_RANGE).mean("longitude")

## get longitudinal means
lat_hov_warm = lon_avg(comps_warm)
lat_hov_cold = lon_avg(comps_cold)


# lat_hov_warm = comps_warm.sel(longitude=slice(210,270)).mean("longitude")
# lat_hov_cold = comps_cold.sel(longitude=slice(210,270)).mean("longitude")

# %%
## specify amplitude
# AMP = 2e-2
AMP = 1.5e-4
# AMP = 3

HOV = lat_hov_warm["pr"]

fig, axs = plt.subplots(3, 1, figsize=(3, 6))

for ax, y in zip(axs, [1870, 1970]):

    ax.contourf(
        HOV.lag,
        HOV.latitude,
        HOV.sel(year=y),
        cmap="cmo.balance",
        levels=src.utils.make_cb_range(AMP, AMP / 5),
        extend="both",
    )

axs[-1].contourf(
    HOV.lag,
    HOV.latitude,
    HOV.sel(year=1980) - HOV.sel(year=1870),
    cmap="cmo.balance",
    levels=src.utils.make_cb_range(AMP / 4, AMP / 20),
    extend="both",
)

for ax in axs:
    ax.set_ylim([-10, 10])
    ax.axhline(0, ls="--", c="k", lw=0.8)
    ax.axvline(2, ls="--", c="w")

# %%
LAG = 2

fig, ax = plt.subplots(figsize=(3, 2.5))
ax.plot(HOV.sel(year=1870, lag=LAG), HOV.latitude)
ax.plot(HOV.sel(year=1980, lag=LAG), HOV.latitude)
# ax.plot(HOV.sel(year=2080,lag=LAG), HOV.latitude)
ax.set_ylim([-10, 10])
# ax.set_ylim([-3e-2, 2e-2])
ax.axvline(0, ls="--", c="k")
ax.axhline(0, ls="--", c="k")

# %% [markdown]
# Same, but including mean state

# %% [markdown]
# ### Asymmetry

# %%
YEAR = 1870

# %% [markdown]
# #### SST

# %%
## set up plot
fig, axs = plt.subplots(1, 3, figsize=(7, 3), layout="constrained")

## plot data
cf = plot_comp_on_axs(
    axs,
    name="sst",
    amp=3.5,
    x1=comps_warm.sel(year=YEAR),
    x0=-comps_cold.sel(year=YEAR),
    nlev=10,
    **hov_kwargs,
)

## label
cb = fig.colorbar(cf, ax=axs[2], ticks=[-30, 30], label="K")

plt.show()

# %% [markdown]
# #### SSH

# %%
## set up plot
fig, axs = plt.subplots(1, 3, figsize=(7, 3), layout="constrained")

## plot data
cf = plot_comp_on_axs(
    axs,
    name="ssh",
    amp=25,
    x1=comps_warm.sel(year=YEAR),
    x0=-comps_cold.sel(year=YEAR),
    nlev=10,
    **hov_kwargs,
)

## label
cb = fig.colorbar(cf, ax=axs[2], ticks=[-30, 30], label="K")

for ax in axs:
    ax.set_xlim([120, None])

plt.show()

# %%
sel_ = lambda x, y: x.sel(year=y, lag=0, latitude=slice(-5, 5)).mean("latitude")

fig, axs = plt.subplots(1, 3, figsize=(8, 2.5))

for ax, y, ls in zip(axs[:-1], [1870, 2070], ["-", "--"]):
    ax.plot(
        comps_warm.longitude,
        -sel_(comps_cold["ssh"], y=y),
        ls=ls,
    )

    ax.plot(
        comps_warm.longitude,
        sel_(comps_warm["ssh"], y=y),
        ls=ls,
    )

    axs[-1].plot(
        comps_warm.longitude,
        sel_(comps_warm["ssh"] + comps_cold["ssh"], y=y),
        ls=ls,
        c="k",
    )

for ax in axs:
    ref_kwargs = dict(ls="--", c="k", lw=0.8)
    ax.axvline(210, **ref_kwargs)
    ax.axhline(0, **ref_kwargs)
    ax.set_xlim([120, 270])

axs[1].set_yticks([])

src.utils.set_lims(axs)

# %% [markdown]
# #### $\tau_x$

# %%
## set up plot
fig, axs = plt.subplots(1, 3, figsize=(7, 3), layout="constrained")

## plot data
cf = plot_comp_on_axs(
    axs,
    name="taux",
    amp=5e-2,
    x1=comps_warm.sel(year=YEAR),
    x0=-comps_cold.sel(year=YEAR),
    nlev=10,
    **hov_kwargs,
)

## label
cb = fig.colorbar(cf, ax=axs[2], ticks=[-30, 30], label="K")

plt.show()

# %% [markdown]
# #### $Z_{20}$

# %%
## set up plot
fig, axs = plt.subplots(1, 3, figsize=(7, 3), layout="constrained")

## plot data
cf = plot_comp_on_axs(
    axs,
    name="z20",
    amp=50,
    x1=comps_warm.sel(year=YEAR),
    x0=-comps_cold.sel(year=YEAR),
    nlev=10,
    **hov_kwargs,
)

## label
cb = fig.colorbar(cf, ax=axs[2], ticks=[-30, 30], label="K")

plt.show()

# %% [markdown]
# #### $Q$

# %%
## set up plot
fig, axs = plt.subplots(1, 3, figsize=(7, 3), layout="constrained")

## plot data
cf = plot_comp_on_axs(
    axs,
    name="Q",
    amp=1,
    x1=comps_warm.sel(year=YEAR),
    x0=-comps_cold.sel(year=YEAR),
    nlev=10,
    **hov_kwargs,
)

## label
cb = fig.colorbar(cf, ax=axs[2], ticks=[-2.5, 0, 2.5], label="K")

plt.show()

# %% [markdown]
# #### budget

# %%
## set up plot
fig, axs = plt.subplots(1, 3, figsize=(7, 3), layout="constrained")

## plot data
cf = plot_comp_on_axs(
    axs,
    name="THF_ml",
    amp=2.5,
    x0=comps_cold.sel(year=1870),
    x1=comps_cold.sel(year=2070),
    nlev=10,
    **hov_kwargs,
)

## label
cb = fig.colorbar(cf, ax=axs[2], ticks=[-2.5, 0, 2.5], label="K")

plt.show()

# %% [markdown]
# ## Hovmollers

# %%
def plot_hovs(comp, varname, amp0, amp1, lag=1, fn=src.utils.get_nino3, delta=False):
    """plot data on hovmoller"""

    ## get data for plot
    plot_data = comp[varname]

    ## make sure latitude is a dimension
    if "latitude" not in plot_data.dims:
        plot_data = plot_data.expand_dims("latitude")

    ## get data for plots
    x0 = plot_data.sel(lag=lag, latitude=slice(-5, 5)).mean("latitude")
    x0 = x0.transpose("year", ...)
    x1 = fn(plot_data).transpose("year", ...)

    ## get delta if necessary
    if delta:
        x0 = x0 - x0.isel(year=0)
        x1 = x1 - x1.isel(year=0)

    fig, axs = plt.subplots(1, 2, figsize=(6, 3), layout="constrained")

    ## longitude on x-axis
    axs[0].contourf(
        x0.longitude,
        x0.year,
        x0,
        cmap="cmo.balance",
        levels=src.utils.make_cb_range(amp0, amp0 / 10),
        extend="both",
    )

    ## lag on x-axis
    axs[1].contourf(
        plot_data.lag,
        plot_data.year,
        x1,
        cmap="cmo.balance",
        levels=src.utils.make_cb_range(amp1, amp1 / 10),
        extend="both",
    )

    axs[0].set_xlim([140, 280])
    axs[0].axvline(210, ls="--", c="k", lw=0.8)
    axs[0].axvline(270, ls="--", c="k", lw=0.8)
    axs[1].axvline(0, ls="--", c="k", lw=0.8)
    axs[0].set_xticks([160, 210, 270])
    axs[0].set_yticks([1870, 1980, 2090])
    axs[1].set_xticks([-3, 0, -3])
    axs[1].set_xlim([-6, 6])
    axs[1].set_yticks([])

    return fig, axs

# %%
## specify month
LAG = 3

## specify composite type
# COMP = comps_warm / comps_warm["T_34"]
# COMP = comps_warm / comps_warm["sst"].sel(latitude=slice(-2,2)).mean("latitude")
COMP = comps_cold / comps_cold["T_34"]

## specify function type
FN = src.utils.get_nino34

## get shared args
kwargs = dict(amp0=0.5, amp1=0.5, lag=LAG, fn=FN, comp=COMP, delta=False)


for VARNAME in ["ddt_T_ml", "THF_ml", "EKM_ml", "ZAF_ml", "DD_ml", "Q"]:

    print(f"\n\n{VARNAME}")
    fig, axs = plot_hovs(varname=VARNAME, **kwargs)
    plt.show()

# %%
sel = lambda x: x.sel(longitude=slice(190, 240)).mean("longitude")
plt.plot(
    comps_warm.year,
    sel((comps_warm / comps_warm["T_3"]).sel(lag=1)["THF_ml"]),
)
plt.axvline(2030)

# %%
plt.plot(
    comps_warm.year,
    src.utils.get_nino34((comps_warm / comps_warm["T_3"]).sel(lag=0)["Q"]),
)
plt.axvline(2030)

# %%
## specify month
# LAG = -3
sel = lambda x: x.sel(lag=slice(-4, 0)).mean("lag")
# sel = lambda x : x.sel(lag=-1)

## specify comp
COMP = comps_cold

## func to select data
prep0 = lambda v: get_nino3_da(COMP[v]) / COMP["T_3"]
prep1 = lambda x: sel((x - x.isel(year=0)))
prep = lambda v: prep1(prep0(v))


fig, axs = plt.subplots(1, 2, figsize=(7, 3))


## positive feedbacks
# for f in ["EKM", "THF", "ZAF", "ADV", "ddt_T"]:
for f in ["ddt_T", "ADV"]:
    axs[0].plot(COMP.year, prep(f"{f}_ml"), label=f)


# negative feedbacks
for f in ["DD_ml", "Q"]:
    axs[1].plot(COMP.year, -prep(f"{f}"), label=f)


## legends
axs[0].legend(prop=dict(size=8))
axs[1].legend(prop=dict(size=8))

for ax in axs:
    ax.axhline(0, ls="--", c="k", lw=0.8)

src.utils.set_lims(axs)

plt.show()

# %% [markdown]
# ## Plot composites of $p$ and $Q$ for El Niño and La Niña

# %%
##### specify month
LAG = 0

## specify composite type
# COMP = comps_warm / comps_warm["T_34"]
COMP = comps_cold / comps_cold["T_34"]

## max longitude
lon_max = COMP.longitude.isel(
    longitude=COMP["pr"]
    .sel(latitude=slice(-5, 5), lag=LAG)
    .mean("latitude")
    .argmax("longitude")
)

## specify function type
FN = src.utils.get_nino34

## get shared args
# VARNAME="pr"
# kwargs = dict(amp0=5e-5, amp1=5e-5, lag=LAG, fn=FN, comp=COMP, delta=False)
VARNAME = "Q"
kwargs = dict(amp0=0.3, amp1=0.3, lag=LAG, fn=FN, comp=COMP, delta=False)


# VARNAME="sst"
# kwargs = dict(amp0=1.5, amp1=1.5, lag=LAG, fn=FN, comp=COMP, delta=False)


fig, axs = plot_hovs(varname=VARNAME, **kwargs)
axs[0].plot(lon_max, COMP.year, c="w", lw=1)


plt.show()

# %%
##### specify month
LAG = 0

## specify composite type
COMP = comps_warm / comps_warm["sst"]
# COMP = comps_cold / comps_cold["T_34"]

## max longitude
lon_max = COMP.longitude.isel(
    longitude=COMP["pr"]
    .sel(latitude=slice(-5, 5), lag=LAG)
    .mean("latitude")
    .argmax("longitude")
)

## specify function type
FN = src.utils.get_nino34

## get shared args
VARNAME = "pr"
kwargs = dict(amp0=5e-5, amp1=5e-5, lag=LAG, fn=FN, comp=COMP, delta=False)
# VARNAME="Q"
# kwargs = dict(amp0=0.3, amp1=0.3, lag=LAG, fn=FN, comp=COMP, delta=False)


# VARNAME="sst"
# kwargs = dict(amp0=1.5, amp1=1.5, lag=LAG, fn=FN, comp=COMP, delta=False)


fig, axs = plot_hovs(varname=VARNAME, **kwargs)
axs[0].plot(lon_max, COMP.year, c="w", lw=1)

axs[0].set_xlim([170, None])
axs[1].set_xlim([None, 1.5])

plt.show()

# %% [markdown]
# formatting function for plots

# %%
def format_ax(ax):

    ## format func
    ax.set_xlim([140, 280])
    ax.axvline(190, ls="--", c="k", lw=0.8)
    ax.axvline(240, ls="--", c="k", lw=0.8)
    ax.set_xticks([150, 190, 240, 270])
    ax.set_yticks([1870, 1980, 2090])
    ax.set_xlabel(r"Longitude")

    return ax

# %%
## specify composite type
COMP_WARM = comps_warm / comps_warm["T_34"]
COMP_COLD = comps_cold / comps_cold["T_34"]

## reduce func
reduce = lambda x: x.sel(latitude=slice(-5, 5)).mean("latitude")

# %%
##### specify month
LAG = 0

fig, axs = plt.subplots(1, 2, figsize=(6, 2.75), layout="constrained")

for ax, COMP in zip(axs, [COMP_WARM, COMP_COLD]):

    ## plot precip
    cp = ax.contourf(
        COMP.longitude,
        COMP.year,
        8.6e4 * reduce(COMP["pr"].sel(lag=LAG)),
        levels=src.utils.make_cb_range(5, 0.5),
        cmap="cmo.balance_r",
        extend="both",
    )

    # ## plot d/dt(T)
    # ax.contour(
    #     COMP.longitude,
    #     COMP.year,
    #     COMP["ddt_T_ml"].sel(lag=LAG) - COMP["ddt_T_ml"].sel(lag=LAG).isel(year=0),
    #     levels=src.utils.make_cb_range(1,.1),
    #     colors="magenta",
    #     extend="both",
    #     linewidths=1
    # )

    ## plot heat flux
    ax.contour(
        COMP.longitude,
        COMP.year,
        reduce(COMP["Q"].sel(lag=LAG)),
        levels=src.utils.make_cb_range(1, 0.1),
        colors="white",
        linewidths=1,
        alpha=0.5,
    )

for ax in axs:
    format_ax(ax)
axs[1].set_yticks([])
axs[0].set_ylabel("Year")
axs[0].set_title("El Niño")
axs[1].set_title("La Niña")

fig.colorbar(cp, ticks=[-5, 0, 5], label=r"$\left(mm~day^{-1}\right) ~K^{-1}$")

plt.show()

# %%
sel_lag = lambda x: x.sel(lag=slice(2, 3)).mean("lag")
# sel_lag = lambda x : x.sel(lag=slice(6,6)).mean("lag")

fig, axs = plt.subplots(1, 2, figsize=(6, 2.75), layout="constrained")

for ax, COMP, scale in zip(axs, [COMP_WARM, COMP_COLD], [1, 4]):

    ## plot precip
    cp = ax.contourf(
        COMP.longitude,
        COMP.year,
        scale * sel_lag(COMP["THF_ml"]),
        levels=src.utils.make_cb_range(2, 0.2),
        # levels=src.utils.make_cb_range(10,1),
        cmap="cmo.balance",
        extend="both",
    )

    # ## plot d/dt(T)
    # ax.contour(
    #     COMP.longitude,
    #     COMP.year,
    #     scale * sel_lag(COMP["ddt_T_ml"] - COMP["ddt_T_ml"].isel(year=0)),
    #     levels=src.utils.make_cb_range(1,.1),
    #     colors="magenta",
    #     extend="both",
    #     linewidths=1
    # )

for ax in axs:
    format_ax(ax)
axs[1].set_yticks([])
axs[0].set_ylabel("Year")
axs[0].set_title("El Niño")
axs[1].set_title("La Niña (x4)")

fig.colorbar(cp, ticks=[-5, 0, 5], label=r"month$^{-1}$")

plt.show()
